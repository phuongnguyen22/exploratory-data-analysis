# %% [markdown]
# ### Data collection

# %%
import pandas as pd
# Read data from a CSV file
data = pd.read_csv('airbnb.csv')

# %% [markdown]
# ### Data Exploration

# %%
# Check the number of rows and columns
data.shape
# Out:
# (7210, 18)

# %%
# Preview first few rows
data.head()
# Out:
#    listing_id    host_id  host_since_datekey  host_response_rate  \
# 0    46096773  349135088            20200608                 NaN
# 1    44692017  361914459            20200812                 NaN
# 2    45841514  371644174            20201012                 NaN
# 3    42228997  314197504            20191203                 NaN
# 4    48115028  387570084            20200429                 NaN
#
#    host_acceptance_rate host_is_superhost  host_total_listings_count  \
# 0                  0.26                 f                        5.0
# 1                  0.34                 f                        0.0
# 2                  0.51                 f                        0.0
# 3                  0.33                 f                        0.0
# 4                  0.64                 f                        0.0
#
#        neighbourhood      city   latitude  longitude           property_type  \
# 0  Enclos-St-Laurent     Paris  48.879289   2.354539           Room in hotel
# ...

# %%
# View column names
data.columns
# Out:
# Index(['listing_id', 'host_id', 'host_since_datekey', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost',
#        'host_total_listings_count', 'neighbourhood', 'city', 'latitude',
#        'longitude', 'property_type', 'accommodates', 'bedrooms', 'price',
#        'review_scores_rating', 'instant_bookable', 'listing_size_sqft'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
# Handling missing values
data.dropna() # Drop rows with missing values
# Out:
#       listing_id    host_id  host_since_datekey  host_response_rate  \
# 26      45888844  371006645            20201007                1.00
# 28      34226790  253838909            20190407                1.00
# 29      39023953  247050783            20190305                1.00
# 30      38340397  291238628            20190903                1.00
# 31      46540298  349682810            20200611                0.12
# ...          ...        ...                 ...                 ...
# 7184    37618764  281589768            20190801                0.90
# 7185    48108583  387569243            20200523                0.90
# 7188    38233759  290524109            20190831                0.00
# 7192    46276527  325882341            20200109                0.98
# 7195    35081594  236039951            20190112                1.00
#
#       host_acceptance_rate host_is_superhost  host_total_listings_count  \
# 26                    0.32                 f                        0.0
# ...

# %%
data.fillna(1) # Fill missing values with a specific value
# Out:
#       listing_id    host_id  host_since_datekey  host_response_rate  \
# 0       46096773  349135088            20200608                 1.0
# 1       44692017  361914459            20200812                 1.0
# 2       45841514  371644174            20201012                 1.0
# 3       42228997  314197504            20191203                 1.0
# 4       48115028  387570084            20200429                 1.0
# ...          ...        ...                 ...                 ...
# 7205    48109312  387561857            20200526                 1.0
# 7206     6569075  235767408            20190110                 1.0
# 7207     7736378  295593456            20190917                 1.0
# 7208     7699700  293573248            20190910                 1.0
# 7209    48114250  387565980            20201025                 1.0
#
#       host_acceptance_rate host_is_superhost  host_total_listings_count  \
# 0                     0.26                 f                        5.0
# ...

# %%
# Removing duplicates
data.drop_duplicates()
# Out:
#       listing_id    host_id  host_since_datekey  host_response_rate  \
# 0       46096773  349135088            20200608                 NaN
# 1       44692017  361914459            20200812                 NaN
# 2       45841514  371644174            20201012                 NaN
# 3       42228997  314197504            20191203                 NaN
# 4       48115028  387570084            20200429                 NaN
# ...          ...        ...                 ...                 ...
# 7205    48109312  387561857            20200526                 1.0
# 7206     6569075  235767408            20190110                 NaN
# 7207     7736378  295593456            20190917                 1.0
# 7208     7699700  293573248            20190910                 1.0
# 7209    48114250  387565980            20201025                 1.0
#
#       host_acceptance_rate host_is_superhost  host_total_listings_count  \
# 0                     0.26                 f                        5.0
# ...

# %%
# Correcting inconsistent data
data['host_response_rate'].replace("NaN", "none", inplace=True)

# %%
data
# Out:
#       listing_id    host_id  host_since_datekey  host_response_rate  \
# 0       46096773  349135088            20200608                 NaN
# 1       44692017  361914459            20200812                 NaN
# 2       45841514  371644174            20201012                 NaN
# 3       42228997  314197504            20191203                 NaN
# 4       48115028  387570084            20200429                 NaN
# ...          ...        ...                 ...                 ...
# 7205    48109312  387561857            20200526                 1.0
# 7206     6569075  235767408            20190110                 NaN
# 7207     7736378  295593456            20190917                 1.0
# 7208     7699700  293573248            20190910                 1.0
# 7209    48114250  387565980            20201025                 1.0
#
#       host_acceptance_rate host_is_superhost  host_total_listings_count  \
# 0                     0.26                 f                        5.0
# ...

# %% [markdown]
# ### Summary Statistics

# %%
# Compute basic summary statistics
data.describe()
# Out:
#          listing_id       host_id  host_since_datekey  host_response_rate  \
# count  7.210000e+03  7.210000e+03        7.210000e+03         4153.000000
# mean   4.159495e+07  3.161178e+08        2.019518e+07            0.846017
# std    5.713025e+06  5.004174e+07        5.211836e+03            0.301183
# min    1.245200e+04  1.336740e+07        2.019010e+07            0.000000
# 25%    3.797416e+07  2.712750e+08        2.019062e+07            0.890000
# 50%    4.228178e+07  3.113271e+08        2.019112e+07            1.000000
# 75%    4.647144e+07  3.649954e+08        2.020061e+07            1.000000
# max    4.811632e+07  3.875705e+08        2.021021e+07            1.000000
#
#        host_acceptance_rate  host_total_listings_count     latitude  \
# count           7210.000000                7202.000000  7210.000000
# mean               0.582302                  12.316301    20.834321
# std                0.197114                 110.517077    35.309111
# ...

# %%
# Calculate mean, median, mode
data.mean()
# Out:
# C:\Users\ThiLanPhuongNguyen\AppData\Local\Temp\ipykernel_16996\264395385.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# listing_id                   4.159495e+07
# host_id                      3.161178e+08
# host_since_datekey           2.019518e+07
# host_response_rate           8.460173e-01
# host_acceptance_rate         5.823024e-01
# host_total_listings_count    1.231630e+01
# latitude                     2.083432e+01
# longitude                    2.578619e+01
# accommodates                 3.182663e+00
# bedrooms                     1.431779e+00
# price                        1.497608e+02
# review_scores_rating         7.512344e+01
# listing_size_sqft            8.735945e+02
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\ThiLanPhuongNguyen\AppData\Local\Temp\ipykernel_16996\3437575075.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# listing_id                   4.228178e+07
# host_id                      3.113271e+08
# host_since_datekey           2.019112e+07
# host_response_rate           1.000000e+00
# host_acceptance_rate         5.700000e-01
# host_total_listings_count    1.000000e+00
# latitude                     4.075765e+01
# longitude                    1.226710e+01
# accommodates                 2.000000e+00
# bedrooms                     1.000000e+00
# price                        8.700000e+01
# review_scores_rating         8.500000e+01
# listing_size_sqft            6.161630e+02
# dtype: float64

# %%
data.mode()
# Out:
#       listing_id      host_id  host_since_datekey  host_response_rate  \
# 0          12452  291007369.0          20190902.0                 1.0
# 1        1858199          NaN                 NaN                 NaN
# 2        4859418          NaN                 NaN                 NaN
# 3        5079785          NaN                 NaN                 NaN
# 4        6304002          NaN                 NaN                 NaN
# ...          ...          ...                 ...                 ...
# 7205    48116307          NaN                 NaN                 NaN
# 7206    48116309          NaN                 NaN                 NaN
# 7207    48116310          NaN                 NaN                 NaN
# 7208    48116312          NaN                 NaN                 NaN
# 7209    48116323          NaN                 NaN                 NaN
#
#       host_acceptance_rate host_is_superhost  host_total_listings_count  \
# ...

# %% [markdown]
# ### Data Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Histogram
plt.hist(data['city'])
# Out:
# (array([1500.,    0.,    0., 2100.,    0.,    0., 1500.,    0.,    0.,
#         2110.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
# Box plot
sns.boxplot(x=data['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
# Scatter plot
plt.scatter(data['price'],
data['price'])

# %%
# Bar chart
sns.countplot(data['review_scores_rating'])
# Out:
# C:\Users\ThiLanPhuongNguyen\anaconda3\envs\Visualisation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='review_scores_rating', ylabel='count'>

# %%
Index(['listing_id', 'host_id', 'host_since_datekey', 'host_response_rate',
       'host_acceptance_rate', 'host_is_superhost',
       'host_total_listings_count', 'neighbourhood', 'city', 'latitude',
       'longitude', 'property_type', 'accommodates', 'bedrooms', 'price',
       'review_scores_rating', 'instant_bookable', 'listing_size_sqft'],
      dtype='object')

# %%
# Heatmap
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlation Analysis

# %%
# Calculate correlation matrix
correlation_matrix = data.corr()
# Heatmap of correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Outlier Detection

# %%
# Box plot
sns.boxplot(x=data['review_scores_rating'])
# Out:
# <AxesSubplot:xlabel='review_scores_rating'>

# %%
# Z-score method
from scipy.stats import zscore
data['z_score'] = zscore(data['review_scores_rating'])
outliers = data[(data['z_score'] > 3) | (data['z_score'] < -3)]

# %% [markdown]
# ### Data Transformation

# %%
data['review_scores_rating'].values
# Out:
# array([18, 88, 75, ..., 96, 98, 98], dtype=int64)

# %%
import numpy as np
# Log transformation
data['log_transformed'] = np.log(data['review_scores_rating'])
# Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data['standardized_column'] = scaler.fit_transform(data['review_scores_rating'].values.reshape(-1, 1))
# Out:
# C:\Users\ThiLanPhuongNguyen\anaconda3\envs\Visualisation\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\ThiLanPhuongNguyen\anaconda3\envs\Visualisation\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Hypothesis Testing

# %%
review_scores_rating

# %%
from scipy.stats import ttest_ind

# Perform t-test between two groups
group1 = data[data['review_scores_rating'] == 88]['price']
group2 = data[data['review_scores_rating'] == 96]['review_scores_rating']
statistic, p_value = ttest_ind(group1, group2)
